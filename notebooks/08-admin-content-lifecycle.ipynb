# %% [markdown]
# # 08 — Admin lifecycle challenge
# Create a draft course/module with the Admin API, upload Markdown, then verify Blob, PostgreSQL, AGE, chatbot, and MCP.

# %%
# Use http://127.0.0.1:8000/docs with ADMIN_API_KEY.
# Verify with: SELECT canonical_filename, storage_uri FROM sources ORDER BY created_at DESC LIMIT 1;
