# %% [markdown]
# # 07 — Student MCP in Claude
# Copy `examples/mcp/claude-desktop.student.example.json`, replace the project path, restart Claude, and ask a course question.

# %%
import asyncio
from course_knowledge.mcp_servers import create_student_server
print([tool.name for tool in asyncio.run(create_student_server().list_tools())])
