# %% [markdown]
# # 01 — Azure OpenAI
# Create an embedding, then compare the dimensions.

# %%
from course_knowledge.embeddings import AzureOpenAIEmbedder
from course_knowledge.settings import azure_openai_settings
embedder = AzureOpenAIEmbedder.from_settings(azure_openai_settings())
vectors = embedder.embed(['Model Context Protocol', 'GitHub Copilot'])
print(len(vectors[0]), len(vectors[1]))
