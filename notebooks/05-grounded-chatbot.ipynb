# %% [markdown]
# # 05 — Grounded chatbot and citations
# Run the web API, ask a question, then inspect citations in the response.

# %%
from course_knowledge.services import CourseKnowledgeService
print(CourseKnowledgeService().ask('What is Model Context Protocol?', moderate=True))
